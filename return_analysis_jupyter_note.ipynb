# %%
# %matplotlib inline
import pandas as pd

# %%
df_return = pd.read_hdf('return.h5')

# %%
df_return.plot(figsize=(16,9))

# %%
df_return.plot.hist(bins=100,figsize=(16,9))

# %%
df_return.describe()
# Out:
# count    514.000000
# mean       0.000166
# std        0.005122
# min       -0.021279
# 25%       -0.001845
# 50%        0.000000
# 75%        0.001991
# max        0.019282
# Name: return, dtype: float64
